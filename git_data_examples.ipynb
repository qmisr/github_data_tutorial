# %% [markdown]
# # Sample Code for Fetching Git Repo Data Using Command Line
# ## The code in this notebook and repository is a companion for the tutorial entitled:
# ## The Challenges and Opportunities Mining GitHub
#
# The notebook is split into sections that show how different data collection tasks can be performed.
#
# Do not forget to look into utils.py and parse_git_stats.py as well.

# %%
# fetch the functions we will use from utils.py
from utils import fetch_github_api_data, search_github
import pandas as pd
from pandas.io.json import json_normalize

# %%
# let's search for some machine learning repos
search_query = "topic:machine-learning"
resource = "repositories"
res = search_github(resource, search_query)
df = json_normalize(res.get("items"))
# Out:
# Fetching data from https://api.github.com/search/repositories params {'q': 'topic:machine-learning', 'per_page': 100}

# %%
# here are a few machine-learning repos
# some of them are software repositories and could be
# examples, tutorials, or even lists
df.full_name
# Out:
# 0                               tensorflow/tensorflow
# 1                                    keras-team/keras
# 2                           scikit-learn/scikit-learn
# 3                   aymericdamien/TensorFlow-Examples
# 4                                          BVLC/caffe
# 5                             tesseract-ocr/tesseract
# 6                           ageitgey/face_recognition
# 7     ZuzooVn/machine-learning-for-software-engineers
# 8                                     JuliaLang/julia
# 9                       Avik-Jain/100-Days-Of-ML-Code
# 10           imhuay/Algorithm_Interview_Notes-Chinese
# 11               terryum/awesome-deep-learning-papers
# 12                           GokuMohandas/practicalAI
# 13                             apache/incubator-mxnet
# 14                                     Microsoft/CNTK
# 15                                       dmlc/xgboost
# 16         donnemartin/data-science-ipython-notebooks
# 17                    oxford-cs-deepnlp-2017/lectures
# 18                                  ageron/handson-ml
# 19                       Developer-Y/cs-video-courses
# 20                                      fastai/fastai
# 21                                    explosion/spaCy
# 22                                       ty4z2008/Qix
# 23              CMU-Perceptual-Computing-Lab/openpose
# 24                      kailashahirwar/cheatsheets-ai
# 25                         mxgmn/WaveFunctionCollapse
# 26         ChristosChristofidis/awesome-deep-learning
# 27                     emilwallner/Screenshot-to-code
# 28                    eriklindernoren/ML-From-Scratch
# 29                                    tensorflow/tfjs
#                            ...
# 70                janishar/mit-deep-learning-book-pdf
# 71                              zalandoresearch/flair
# 72                                  EpistasisLab/tpot
# 73                             dotnet/machinelearning
# 74                     ramitsurana/awesome-kubernetes
# 75                                   PAIR-code/facets
# 76                                       aleju/imgaug
# 77                                Hironsan/BossSensor
# 78                      zalandoresearch/fashion-mnist
# 79                              spmallick/learnopencv
# 80                                      pyro-ppl/pyro
# 81                        hindupuravinash/the-gan-zoo
# 82                                SerpentAI/SerpentAI
# 83                                     guess-js/guess
# 84                                 jhfjhfj1/autokeras
# 85                                    RasaHQ/rasa_nlu
# 86                       lexfridman/mit-deep-learning
# 87                          wiseodd/generative-models
# 88                            tensorlayer/tensorlayer
# 89                                    liuruoze/EasyPR
# 90              humphd/have-fun-with-machine-learning
# 91                                    chainer/chainer
# 92                                  tiny-dnn/tiny-dnn
# 93                         rushter/data-science-blogs
# 94         owainlewis/awesome-artificial-intelligence
# 95                                 lanpa/tensorboardX
# 96                              transcranial/keras-js
# 97                                   thtrieu/darkflow
# 98                     kmario23/deep-learning-drizzle
# 99                           astorfi/TensorFlow-World
# Name: full_name, Length: 100, dtype: object

# %% [markdown]
# # Working With Repo MetaData or Source Code
# Before we can analyze a repository, we have to select the projects we want to work with.
#
# We have searched for repositories that fall under the machine-learning topic.
#
# To see how we could randomly sample these repositories, see the [github_api_examples notebook](./github_api_example.ipynb)
#
# We will perform the analysis on `tensorflow/tensorflow`.
#
# The main steps are:
# 1. Clone the repository. This requires that we dedicate a directory to store the cloned repositories to.
# 2. Use python **subprocess** library Run the appropriate command line git commands to display information
# 3. Extract the information using Python

# %%
# To clone a git repository use utils.clone_git_repo
from utils import clone_git_repo
from parse_git_stats import get_git_stats_for_project

# %%
# df with single entry for tensorflow/tensorflow repo
repo_data = df[df.full_name == "tensorflow/tensorflow"]

# %%
# this is how you iterate rows in a DF
for idx, row in repo_data.iterrows():
    # we need the full name and the clone url
    full_name = row.get("full_name")
    clone_url = row.get("clone_url")
    
    # now we can clone the repository
    # You have to wait until it is cloned
    # if you know the name and url then you can clone with this command only
    clone_git_repo(full_name, clone_url)
    
    # fetch project data
    git_stats_df = get_git_stats_for_project(full_name, start_year=2019, end_year=2020)
    
    # NOTE: problematic diffs are when that there are likely no changes to analyze
# Out:
# Repo exists in tensorflow_tensorflow, not going to clone.
# working on period 1, start: 2019-01-01 00:00:00, end: 2019-02-01 00:00:00
# problem in diff 96007e5022df35766b014a30d6fe4075cc1662cc, 76b2438b24ea1d541dd93af5c76067d5c901ea2a item: ['']
# problem in diff 76b2438b24ea1d541dd93af5c76067d5c901ea2a, 4e06198e15ca222ac2d32a24ed4b7133f720118e item: ['']
# problem in diff ef15adf25bd1d73840ab3dab68b5ed13b2bedb96, ce955e38598c47129910f4fd4cbef1402f5a3ddd item: ['']
# problem in diff af820d5b364486165d4996a3eebe63f8c0a19a94, 898738bce44c0cfdaa36b1dfc865239eb48fa999 item: ['']
# problem in diff 50acc0c4f34b28013fc2b122b68aa135ecb0b197, ac40a68cd5fac2227fb6c4086b2eb01a7dc726c4 item: ['']
# working on period 2, start: 2019-02-01 00:00:00, end: 2019-03-01 00:00:00
# working on period 3, start: 2019-03-01 00:00:00, end: 2019-04-01 00:00:00
# problem in diff 718bdbdb48b7f383e3f6f4003fff298ad187f646, 5b8d7d0fa266361f6d3ab86fce5c9ae3107eab39 item: ['']
# no revisions between 2019-04-01 00:00:00 and 2019-05-01 00:00:00
# no revisions between 2019-05-01 00:00:00 and 2019-06-01 00:00:00
# no revisions between 2019-06-01 00:00:00 and 2019-07-01 00:00:00
# no revisions between 2019-07-01 00:00:00 and 2019-08-01 00:00:00
# no revisions between 2019-08-01 00:00:00 and 2019-09-01 00:00:00
# no revisions between 2019-09-01 00:00:00 and 2019-10-01 00:00:00
# no revisions between 2019-10-01 00:00:00 and 2019-11-01 00:00:00
# no revisions between 2019-11-01 00:00:00 and 2019-12-01 00:00:00
# no revisions between 2019-12-01 00:00:00 and 2020-01-01 00:00:00

# %%
# The data is quite rich
# please take the time to review it
git_stats_df.T
# Out:
#                                                                              0  \
# full_name                                                tensorflow/tensorflow
# date                                                       2019-01-01 00:00:00
# end_date                                                   2019-02-01 00:00:00
# period                                                                       1
# total_revs                                                                1862
# first_rev                             31723c74caf0cf3effb46e12de00eb80ae86a899
# last_rev                              15d49deb3c5d4048718af19a2e0e0279e8f204d5
# new_contribs                                                                43
# new_committers                                                               0
# total_contribs                                                             210
# committers_for_others                                                        3
# total_committers                                                            69
# mean_contribs                                                           8.6619
# median_contribs                                                              3
# std_contribs                                                           39.3725
# max_contribs                                                               570
# min_contribs                                                                 1
# top_conrib_ratio                                                      0.313359
# bottom_conrib_ratio                                                0.000549753
# conrib_ratio                 [0.0005497526113249038, 0.0005497526113249038,...
# mean_commits                                                           26.3623
# median_commits                                                               2
# std_commits                                                            177.161
# max_commits                                                               1486
# min_commits                                                                  1
# top_commits_ratio                                                     0.816932
# bottom_commits_ratio                                               0.000549753
# commits_ratio                [0.0005497526113249038, 0.0005497526113249038,...
# mean_commits_others                                                        321
# median_commits_others                                                       45
# std_commits_others                                                     421.095
# max_commits_others                                                         916
# min_commits_others                                                           2
# top_commits_others_ratio                                              0.951194
# bottom_commits_others_ratio                                         0.00207684
# commit_for_others_ratios     [0.0020768431983385254, 0.04672897196261682, 0...
# initial_commit_date                                                 2015-11-07
# age_days                                                                  1232
# releases                                                           v1.13.0-rc0
# no_releases                                                                  1
# refactors                                                                   25
# fixes_can_be_doc                                                           375
# not_fixes_can_be_doc                                                      1311
# fixes_and_doc                                                               20
# fixes_no_doc                                                               355
# docs                                                                        67
# commits_no_merge                                                          1686
# merges                                                                     176
# total_commits                                                             1862
# files_changed_churn                                                     278651
# loc_added_churn                                                        8419534
# loc_removed_churn                                                      8516720
# files_changed_delta                                                       3123
# loc_added_delta                                                          55961
# loc_removed_delta                                                       153140
#
#                                                                              1  \
# full_name                                                tensorflow/tensorflow
# date                                                       2019-02-01 00:00:00
# end_date                                                   2019-03-01 00:00:00
# period                                                                       2
# total_revs                                                                2070
# first_rev                             0b5d09d515ea6f54f949c600a585291b9ff05ea8
# last_rev                              9cb9320acefb13bf1d7983a2e116c0933d89358c
# new_contribs                                                                50
# new_committers                                                               0
# total_contribs                                                             218
# committers_for_others                                                        5
# total_committers                                                            64
# mean_contribs                                                          9.42202
# median_contribs                                                              3
# std_contribs                                                           43.0793
# max_contribs                                                               630
# min_contribs                                                                 1
# top_conrib_ratio                                                      0.306719
# bottom_conrib_ratio                                                0.000486855
# conrib_ratio                 [0.0004868549172346641, 0.0004868549172346641,...
# mean_commits                                                           32.0938
# median_commits                                                               2
# std_commits                                                             198.14
# max_commits                                                               1596
# min_commits                                                                  1
# top_commits_ratio                                                      0.77702
# bottom_commits_ratio                                               0.000486855
# commits_ratio                [0.0004868549172346641, 0.0004868549172346641,...
# mean_commits_others                                                      226.8
# median_commits_others                                                        1
# std_commits_others                                                     375.018
# max_commits_others                                                         966
# min_commits_others                                                           1
# top_commits_others_ratio                                              0.851852
# bottom_commits_others_ratio                                        0.000881834
# commit_for_others_ratios     [0.0008818342151675485, 0.0008818342151675485,...
# initial_commit_date                                                 2015-11-07
# age_days                                                                  1232
# releases                                       v1.13.0-rc1,v1.13.0-rc2,v1.13.1
# no_releases                                                                  3
# refactors                                                                   25
# fixes_can_be_doc                                                           354
# not_fixes_can_be_doc                                                      1491
# fixes_and_doc                                                               20
# fixes_no_doc                                                               334
# docs                                                                        62
# commits_no_merge                                                          1845
# merges                                                                     225
# total_commits                                                             2070
# files_changed_churn                                                     351526
# loc_added_churn                                                       13493694
# loc_removed_churn                                                     13661848
# files_changed_delta                                                       3724
# loc_added_delta                                                         125313
# loc_removed_delta                                                       293444
#
#                                                                              2
# full_name                                                tensorflow/tensorflow
# date                                                       2019-03-01 00:00:00
# end_date                                                   2019-04-01 00:00:00
# period                                                                       3
# total_revs                                                                1511
# first_rev                             36f817a9f3e7d2339cb53b91ddc508b3e25ab761
# last_rev                              fdbaab6f506a1829cbadaf79482ffc95a7342b37
# new_contribs                                                                36
# new_committers                                                               0
# total_contribs                                                             189
# committers_for_others                                                        2
# total_committers                                                            50
# mean_contribs                                                          7.78836
# median_contribs                                                              3
# std_contribs                                                           37.4698
# max_contribs                                                               515
# min_contribs                                                                 1
# top_conrib_ratio                                                      0.349864
# bottom_conrib_ratio                                                0.000679348
# conrib_ratio                 [0.0006793478260869565, 0.0006793478260869565,...
# mean_commits                                                             29.44
# median_commits                                                               2
# std_commits                                                            167.457
# max_commits                                                               1200
# min_commits                                                                  1
# top_commits_ratio                                                     0.815217
# bottom_commits_ratio                                               0.000679348
# commits_ratio                [0.0006793478260869565, 0.0006793478260869565,...
# mean_commits_others                                                      362.5
# median_commits_others                                                    362.5
# std_commits_others                                                       322.5
# max_commits_others                                                         685
# min_commits_others                                                          40
# top_commits_others_ratio                                              0.944828
# bottom_commits_others_ratio                                          0.0551724
# commit_for_others_ratios             [0.05517241379310345, 0.9448275862068966]
# initial_commit_date                                                 2015-11-07
# age_days                                                                  1232
# releases                                                         v2.0.0-alpha0
# no_releases                                                                  1
# refactors                                                                   27
# fixes_can_be_doc                                                           262
# not_fixes_can_be_doc                                                      1056
# fixes_and_doc                                                               12
# fixes_no_doc                                                               250
# docs                                                                        49
# commits_no_merge                                                          1318
# merges                                                                     193
# total_commits                                                             1511
# files_changed_churn                                                     143033
# loc_added_churn                                                        5868194
# loc_removed_churn                                                      5999540
# files_changed_delta                                                       2205
# loc_added_delta                                                          61196
# loc_removed_delta                                                       192542

# %%
# store as CSV without the pandas index
git_stats_df.to_csv("gitstats.csv", index=False)
